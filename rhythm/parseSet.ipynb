# %%
import numpy as np
from music21 import *

us = environment.UserSettings()
#us['musescoreDirectPNGPath'] = '/usr/bin/mscore3'
#us['musicxmlPath'] = '/usr/bin/mscore3'

# %%
def parse(file):
        with open(file) as f:
            count = 1
            for line in f.readlines():
                if count == 5:
                    txt = line
                count += 1
        x = txt.split()
        note_number = []
        for i in x:
            if (i[:6]) == 'chosen':
                note_number.append(i[11:])
        note_number_rem = []
        # Remove last bracket
        for i in note_number:
            note_number_rem.append(i[:len(i)-1])
        note_dict = {}
        for i in note_number_rem:
            split = i.split(',')
            note_dict[int(split[1])] = split[0]
        note_dict_sort = {}
        for key in sorted(note_dict.keys()) :
            note_dict_sort[key] = int(note_dict[key])
        return(note_dict_sort)
            
def create_notes(clef, num):
    # Create notes
    note1 = note.Note('C' + num)
    note2 = note.Note('C' + num)
    note3 = note.Note('C' + num)
    note4 = note.Note('C' + num)
    note5 = note.Note('C' + num)
    note6 = note.Note('C' + num)
    note7 = note.Note('C' + num)
    note8 = note.Note('C' + num)
    note9 = note.Note('C' + num)
    note10 = note.Note('C' + num)
    note11 = note.Note('C' + num)
    note12 = note.Note('C' + num)
    note13 = note.Note('C' + num)
    note14 = note.Note('C' + num)
    note15 = note.Note('C' + num)
    note16 = note.Note('C' + num)
    note17 = note.Note('C' + num)
    note18 = note.Note('C' + num)
    note19 = note.Note('C' + num)
    note20 = note.Note('C' + num)
    note21 = note.Note('C' + num)
    note22 = note.Note('C' + num)
    
     # Add rhythm 
    if clef == bass_clef:
        note1.duration.quarterLength = 0.75
    if clef == bass_clef:
        note2.duration.quarterLength = 0.25
    if clef == bass_clef:
        note3.duration.quarterLength = 0.75
    if clef == bass_clef:
        note4.duration.quarterLength = 0.25
    if clef == bass_clef:
        note5.duration.quarterLength = 1
    if clef == bass_clef:
        note6.duration.quarterLength = 1
    if clef == bass_clef:
        note7.duration.quarterLength = 0.75
    if clef == bass_clef:
        note8.duration.quarterLength = 0.25
    if clef == bass_clef:
        note9.duration.quarterLength = 0.75
    if clef == bass_clef:
        note10.duration.quarterLength = 0.25
    if clef == bass_clef:
        note11.duration.quarterLength = 2
    if clef == bass_clef:
        note12.duration.quarterLength = 0.75
    if clef == bass_clef:
        note13.duration.quarterLength = 0.25
    if clef == bass_clef:
        note14.duration.quarterLength = 0.75
    if clef == bass_clef:
        note15.duration.quarterLength = 0.25
    if clef == bass_clef:
        note16.duration.quarterLength = 1
    if clef == bass_clef:
        note17.duration.quarterLength = 1
    if clef == bass_clef:
        note18.duration.quarterLength = 0.75
    if clef == bass_clef:
        note19.duration.quarterLength = 0.25
    if clef == bass_clef:
        note20.duration.quarterLength = 0.75
    if clef == bass_clef:
        note21.duration.quarterLength = 0.25
    if clef == bass_clef:
        note22.duration.quarterLength = 2
        
    
    # Add notes to stream
    stream1 = stream.Part([clef])
    stream1.append(note1)
    stream1.append(note2)
    stream1.append(note3)
    stream1.append(note4)
    stream1.append(note5)
    stream1.append(note6)
    stream1.append(note7)
    stream1.append(note8)
    stream1.append(note9)
    stream1.append(note10)
    stream1.append(note11)
    stream1.append(note12)
    stream1.append(note13)
    stream1.append(note14)
    stream1.append(note15)
    stream1.append(note16)
    stream1.append(note17)
    stream1.append(note18)
    stream1.append(note19)
    stream1.append(note20)
    stream1.append(note21)
    stream1.append(note22)
    
    return(stream1)

def create_notes_guitar(clef, num):
    
    # Create notes
    note1 = note.Note('C' + num)
    note2 = note.Note('C' + num)
    note3 = note.Note('C' + num)
    note4 = note.Note('C' + num)
    note5 = note.Note('C' + num)
    note6 = note.Note('C' + num)
    note7 = note.Note('C' + num)
    note8 = note.Note('C' + num)
    note9 = note.Note('C' + num)
    note10 = note.Note('C' + num)
    note11 = note.Note('C' + num)
    note12 = note.Note('C' + num)
    note13 = note.Note('C' + num)
    note14 = note.Note('C' + num)
    note15 = note.Note('C' + num)
    note16 = note.Note('C' + num)
    note17 = note.Note('C' + num)
    note18 = note.Note('C' + num)
    note19 = note.Note('C' + num)
    note20 = note.Note('C' + num)
    note21 = note.Note('C' + num)
    note22 = note.Note('C' + num)
    note23 = note.Note('C' + num)
    note24 = note.Note('C' + num)
    note25 = note.Note('C' + num)
    note26 = note.Note('C' + num)
    note27 = note.Note('C' + num)
    note28 = note.Note('C' + num)
    note29 = note.Note('C' + num)
    note30 = note.Note('C' + num)
    
     # Add rhythm 
    if clef == treble_clef:
        note1.duration.quarterLength = 0.3333333
        note2.duration.quarterLength = 0.3333333
        note3.duration.quarterLength = 0.3333333
        note4.duration.quarterLength = 0.3333333
        note5.duration.quarterLength = 0.3333333
        note6.duration.quarterLength = 0.3333333
        note7.duration.quarterLength = 1
        note8.duration.quarterLength = 1
        note9.duration.quarterLength = 0.3333333
        note10.duration.quarterLength = 0.3333333
        note11.duration.quarterLength = 0.3333333
        note12.duration.quarterLength = 0.3333333
        note13.duration.quarterLength = 0.3333333
        note14.duration.quarterLength = 0.3333333
        note15.duration.quarterLength = 2
        note16.duration.quarterLength = 0.3333333
        note17.duration.quarterLength = 0.3333333
        note18.duration.quarterLength = 0.3333333
        note19.duration.quarterLength = 0.3333333
        note20.duration.quarterLength = 0.3333333
        note21.duration.quarterLength = 0.3333333
        note22.duration.quarterLength = 1
        note23.duration.quarterLength = 1
        note24.duration.quarterLength = 0.3333333
        note25.duration.quarterLength = 0.3333333
        note26.duration.quarterLength = 0.3333333
        note27.duration.quarterLength = 0.3333333
        note28.duration.quarterLength = 0.3333333
        note29.duration.quarterLength = 0.3333333
        note30.duration.quarterLength = 2
        
    
    # Add notes to stream
    stream1 = stream.Part([clef])
    stream1.append(note1)
    stream1.append(note2)
    stream1.append(note3)
    stream1.append(note4)
    stream1.append(note5)
    stream1.append(note6)
    stream1.append(note7)
    stream1.append(note8)
    stream1.append(note9)
    stream1.append(note10)
    stream1.append(note11)
    stream1.append(note12)
    stream1.append(note13)
    stream1.append(note14)
    stream1.append(note15)
    stream1.append(note16)
    stream1.append(note17)
    stream1.append(note18)
    stream1.append(note19)
    stream1.append(note20)
    stream1.append(note21)
    stream1.append(note22)
    stream1.append(note23)
    stream1.append(note24)
    stream1.append(note25)
    stream1.append(note26)
    stream1.append(note27)
    stream1.append(note28)
    stream1.append(note29)
    stream1.append(note30)
    
    return(stream1)
def to_stream(dic, stream1):
        count = 1
        for key in dic:
            z = dic[key]
            if z == 1:
                pass
            if z == 2:
                stream1[count].transpose(1, inPlace=True)
            if z == 3:
                #stream1.append(note.Note('d' + num))
                stream1[count].transpose(2, inPlace=True)
            if z == 4:
                #stream1.append(note.Note('eb' + num))
                stream1[count].transpose(3, inPlace=True)
            if z == 5:
                #stream1.append(note.Note('e' + num))
                stream1[count].transpose(4, inPlace=True)
            if z == 6:
                #stream1.append(note.Note('f' + num))
                stream1[count].transpose(5, inPlace=True)
            if z == 7:
                #stream1.append(note.Note('f#' + num))
                stream1[count].transpose(6, inPlace=True)
            if z == 8:
                #stream1.append(note.Note('g' + num))
                stream1[count].transpose(7, inPlace=True)
            if z == 9:
                #stream1.append(note.Note('ab' + num))
                stream1[count].transpose(8, inPlace=True)
            if z == 10:
                #stream1.append(note.Note('a' + num))
                stream1[count].transpose(9, inPlace=True)
            if z == 11:
                #stream1.append(note.Note('bb' + num))
                stream1[count].transpose(10, inPlace=True)
            if z == 12:
                #stream1.append(note.Note('b' + num))
                stream1[count].transpose(11, inPlace=True)
            count += 1
        return(stream1)

# %%
s = stream.Stream()
bass_clef = clef.BassClef()
treble_clef = clef.TrebleClef()


bass = to_stream(parse('bass'), create_notes(bass_clef, '2')) 
guitar = to_stream(parse('guitar'), create_notes_guitar(treble_clef, '4'))
s.insert(guitar)
s.insert(bass)
s.show('midi')
s.show()
s.write('midi', 'composition.mid')
# Out:
#                 <div id='midiPlayerDiv499'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv499');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
# 'composition.mid'
